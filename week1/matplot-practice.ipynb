# %% [markdown]
# # `Practice Set 1:`

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

plt.style.use('default')

# %% [markdown]
# ## `Problem 1 to 5:`
#
# Dataset link: https://tinyurl.com/2fe6vz4u
#
# **Add a label to every axis and add a proper title for the charts. Also add proper labels if there are multiple representations.** Then, you can customize it as your wish.

# %% [markdown]
# ## Question 1:
#  Draw a line plot of which, the x-axis is the "Year" and the y-axis is sum of "PM2.5" of two countries Iran and China.

# %%
df = pd.read_csv("E:/ai-learning/data/List of most-polluted cities by particulate matter concentration - List of most-polluted cities by particulate matter concentration.csv")
#display(df.head())

countries = ['Iran', 'China']
country_df = df[df['Country'].isin(countries)]

data = country_df.groupby(['Year', 'Country'])['PM2.5'].sum().reset_index()

iran_df = data[data['Country'] == 'Iran']
china_df = data[data['Country'] == 'China']

plt.figure(figsize=(10,5))
plt.plot(iran_df['Year'], iran_df['PM2.5'], label='Iran', linewidth=3)
plt.plot(china_df['Year'], china_df['PM2.5'], label='China', linewidth=3)

plt.title("Year vs Sum of PM2.5 (Iran and China)")
plt.xlabel('Years')
plt.ylabel ('Sum of PM2.5')
plt.xticks(data['Year'])
plt.grid()

plt.legend()
plt.show()

# %% [markdown]
# ## Question 2:
# Draw a histogram of the column "PM10" of which the y-axis represents the probability (see the documentation how to draw the probability).

# %%
plt.hist(df['PM10'], density=True, bins=50, facecolor= 'purple')
plt.xlabel('Bins')
plt.ylabel('Pribability')
plt.title('Histogram of PM10')
plt.grid()

plt.show()

# %% [markdown]
# ## Question 3:
# Draw a scatter plot where x-axis represents "PM2.5" and y-axis represents "PM10" for two countries Poland and Chile

# %%
poland_df = df[df['Country'] == 'Poland']
chile_df = df[df['Country'] == 'Chile']

plt.scatter(poland_df['PM2.5'], poland_df['PM10'], marker='+', color='red', linewidth=3, s=75, label='Poland')
plt.scatter(chile_df['PM2.5'], chile_df['PM10'], marker='o', color='green', label='Chile')
plt.xlabel('PM2.5')
plt.ylabel('PM10')
plt.title('PM2.5 vs PM10 for Chile and Poland')
plt.grid()
plt.legend()

plt.show()

# %% [markdown]
# ## Question 4:
# Draw a pie chart of top 5 most frequent countries.

# %%
top_5_countries = df["Country"].value_counts().head(5)

plt.pie(top_5_countries, labels=top_5_countries.index, autopct='%0.1f%%', shadow=True)
plt.show()

# %% [markdown]
# ## Question 5:
# Draw a bar chart which represents the counts of top 5 most frequent countries.

# %%
plt.bar(top_5_countries.index, top_5_countries)
plt.title("Top 5 frequent Countries")
plt.xlabel('Countries')
plt.ylabel('Frequency Count')
plt.show()

# %% [markdown]
# ##`Problem 6-10:`
# Data Set - https://docs.google.com/spreadsheets/d/e/2PACX-1vTJh6X4_mqixWsfK9mgkllGQkKYW9Wj9kOIMGY2uYsWeS8n5np87DO-SDGQWJ1HXEnxiOVFVzYFYEcR/pub?gid=558678488&single=true&output=csv
#
# This is a Sales data of any company in a Year.

# %% [markdown]
# ## Question 6:
# Show a line plot of Total Profit for each month with below styling.
# * Dotted Line
# * Line Color Blue
# * Show Legend at top left
# * Circle Marker

# %%
df = pd.read_csv("E:/ai-learning/data/company_sales_data - company_sales_data.csv")


plt.plot(df['month_number'], df['total_profit'], label='Profit on Month', marker='o', linestyle='dotted', color='blue')

plt.title('Company Sales Profit')
plt.xlabel('Months')
plt.ylabel('Profit')
plt.legend(loc='upper left')
plt.grid()

plt.show()

# %% [markdown]
# ## Question 7:
# Show sales of each product in march month as pie chart.
# * Show Percentage value
# * Give Title "Sales in March"
# * Explode ToothPaste with shadow

# %%
labels = df[df['month_number'] == 3].iloc[:, 1:7].stack().index.get_level_values(1)
print(labels)
values = df[df['month_number'] == 3].iloc[:, 1:7].stack().values
print(values)

plt.pie(values, labels=labels, autopct='%0.1f%%', shadow=True, explode=[0, 0, 0.1, 0, 0, 0])
plt.title("Sales in March")

plt.show
# Out:
# Index(['facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo',
#        'moisturizer'],
#       dtype='str')
# [2140 1340 4550 9550 3550 1340]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Question 8:
# Show Quarter wise Sales data for all products as multi Bar chart.

# %%
df['Quarter'] = (df['month_number'] - 1) // 3 + 1


quarter_sales = df.groupby('Quarter')[[
    'facecream',
    'facewash',
    'toothpaste',
    'bathingsoap',
    'shampoo',
    'moisturizer'
]].sum()

display(quarter_sales)
width = 0.13
x = np.arange(len(quarter_sales.index))

plt.figure(figsize=(10, 6))
plt.bar(x - 2.5 * width, quarter_sales['facecream'], width, label='Facecream')
plt.bar(x - 1.5 * width, quarter_sales['facewash'], width, label='Facewash')
plt.bar(x - 0.5 * width, quarter_sales['toothpaste'], width, label='Toothpaste')
plt.bar(x + 0.5 * width, quarter_sales['bathingsoap'], width, label='Bathinngsoap')
plt.bar(x + 1.5 * width, quarter_sales['shampoo'], width, label='Shampoo')
plt.bar(x + 2.5 * width, quarter_sales['moisturizer'], width, label='moisturizer')
plt.xlabel("Quarter")
plt.ylabel("Sales")
plt.xticks(x, labels=['Q1', 'Q2', 'Q3', 'Q4 '])
plt.legend()

plt.show()
# Out:
#          facecream  facewash  toothpaste  bathingsoap  shampoo  moisturizer
# Quarter
# 1             7270      4040       14850        24850     6850         4040
# 2             9760      4425       15320        24120     5320         4425
# 3            10220      4300       16740        27040     6740         4300
# 4             7230      5750       23000        38000     6500         5750

# %% [markdown]
# # `Practice Set 2:`

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('default')

# %% [markdown]
# ## **Problem 1 to 2:**
#
# **Dataset link:** https://rb.gy/gsmddu
#
# **Add a label to every axis and add a proper title for the charts (For every subplot, it is applicable). Also add proper labels if there are multiple representations.** Then, you can customize it as your wish.

# %% [markdown]
# ### **Problem-1:** Make a subplots which have 2 plots.
#
# - For the first chart, draw a scatter plot "*Monitored Cap.(MW)*" vs "*Total Cap. Under Maintenance (MW)*" of top 5 most frequent power stations. Then draw the lines which indicate the average values of these two columns. Change the colors according to the names of the Power Stations.
# - For the second chart, draw a scatter plot "*Monitored Cap. (MW)*" vs "*Actual(MU)*" of the top 5 most frequent power stations. Also draw the lines which indicates the average values of these two columns. Change the colors according to the names of the Power Stations.

# %%
df = pd.read_csv("E:/ai-learning/data/PowerGeneration - PowerGeneration.csv")

# we need to make a scatter plot of top 5 frequent power stations
frequent_power_stations = df['Power Station'].value_counts().head(5).reset_index()

frequent_power_stations = df[df['Power Station'].isin(frequent_power_stations['Power Station'])]

# now find the avg values of these col Monitored Cap.(MW) and Total Cap. Under Maintenace (MW)
avg_monitored = frequent_power_stations['Monitored Cap.(MW)'].mean()
avg_maintenance = frequent_power_stations['Total Cap. Under Maintenace (MW)'].mean() 
avg_actual_mu = frequent_power_stations['Actual(MU)'].mean()

# graph 1:
fig, ax = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(12,8))

for station, station_data in frequent_power_stations.groupby('Power Station'):
    ax[0].scatter(station_data['Monitored Cap.(MW)'], station_data['Total Cap. Under Maintenace (MW)'], label=station)

ax[0].set_ylabel('Total Cap. Under Maintenace (MW)')
ax[0].set_title('Monitored vs Maintenance (Top 5 frequent Power Stations)')
ax[0].axvline(avg_monitored, color='green', linestyle='dashed', label='Average Monitored')
ax[0].axhline(avg_maintenance, color='red', linestyle='dashed',  label='Average Maintenance')
ax[0].grid()
ax[0].legend() 

# graph 2
for station, station_data in frequent_power_stations.groupby('Power Station'):
    ax[1].scatter(station_data['Monitored Cap.(MW)'], station_data['Actual(MU)'], label=station)
ax[1].set_xlabel('Monitored Cap.(MW)')
ax[1].set_ylabel('Actual(MU)')
ax[1].axvline(avg_monitored, color='green', linestyle='dashed', label='Average Monitored')
ax[1].axhline(avg_actual_mu, color='red', linestyle='dashed',  label='Average Actual(MU)')
ax[1].grid()
ax[1].legend()

plt.show()

# %% [markdown]
# ## **Problem-2:**
# Draw a 3D Scatter plot between "*Monitored Cap.(MW)*", "*Total Cap. Under Maintenace (MW)*" and "*Forced Maintanence(MW)*"

# %%
fig = plt.figure(figsize=(12,8))
ax = plt.subplot(projection='3d')

ax.scatter3D(df['Monitored Cap.(MW)'], df['Total Cap. Under Maintenace (MW)'], df['Forced Maintanence(MW)'])
ax.set_xlabel('Monitored Cap.(MW)')
ax.set_ylabel('Total Cap. Under Maintenace (MW)')
ax.set_zlabel('Forced Maintanence(MW)', labelpad=-1)

plt.show()

# %% [markdown]
# ## **Problem-3:**
# Make a 3D *Surface* plot of this below mathematical equation.
#
# $$z = |x| - |y|$$

# %%
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)

xx, yy = np.meshgrid(x, y)

z = np.abs(xx) - np.abs(yy)

fig = plt.figure(figsize=(12, 8))
ax = plt.subplot(projection='3d')

graph = ax.plot_surface(xx, yy, z, cmap='viridis')
fig.colorbar(graph)

plt.show()

# %% [markdown]
# ## **Problem-4:**
#  Draw the 3D *Contour plot* of this below equation:
#
# $$z = |x| - |y|$$

# %%
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)

xx, yy = np.meshgrid(x, y)

z = np.abs(xx) - np.abs(yy)

fig = plt.figure(figsize=(12, 8))
ax = plt.subplot()

graph = ax.contour(xx, yy, z, cmap='viridis')
fig.colorbar(graph)

plt.show()

# %% [markdown]
# ## **Problem-5:**
# Draw a second type of Countour plot of the below equation:
#
# $$z = |x| - |y|$$

# %%
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)

xx, yy = np.meshgrid(x, y)

z = np.abs(xx) - np.abs(yy)

fig = plt.figure(figsize=(12, 8))
ax = plt.subplot()

graph = ax.contourf(xx, yy, z, cmap='viridis')
fig.colorbar(graph)

plt.show()

# %% [markdown]
# ## **Problem-6:**
# Create a 3-D Scatter Plot using `time,x,y` on below synthetic data. and give color gradiant on `z`
# ```
# # Create a 3D dataset
# time = np.linspace(0, 10, 100)
# x = np.sin(time)
# y = np.cos(time)
# z = time
#
# # Create a DataFrame from the dataset
# data = pd.DataFrame({'time': time, 'x': x, 'y': y, 'z': z})
# ```

# %%
time = np.linspace(0, 10, 100)
x = np.sin(time)
y = np.cos(time)
z = time

# Create a DataFrame from the dataset
data = pd.DataFrame({'time': time, 'x': x, 'y': y, 'z': z})

fig = plt.figure(figsize=(12,8))
ax = plt.subplot(projection='3d')

scatter = ax.scatter3D(data['x'], data['y'], data['z'], c=data['z'], cmap='viridis')

ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z (Time)")
ax.set_title("3D Scatter Plot with Color Gradient")

cbar = plt.colorbar(scatter)
cbar.set_label("Z (Time)")

plt.show()

# %% [markdown]
# ### **Problem 7:**
#  Create a surface plot and the 2 types of the contour plots of the below equation.
#
# $$z = sin(\sqrt{x^2 + y^2})$$

# %%
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)

xx, yy = np.meshgrid(x, y)

z = np.sin(np.sqrt(xx**2 + yy**2))

fig = plt.figure(figsize=(12, 8))
ax = plt.subplot(projection='3d')

graph = ax.plot_surface(xx, yy, z, cmap='viridis')
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
fig.colorbar(graph)

plt.show()

# %%
fig = plt.figure(figsize=(12, 8))
ax = plt.subplot()

graph = ax.contour(xx, yy, z, cmap='viridis')
ax.set_xlabel("X")
ax.set_ylabel("Y")
fig.colorbar(graph)


plt.show()

# %%
fig = plt.figure(figsize=(12, 8))
ax = plt.subplot()

graph = ax.contourf(xx, yy, z, cmap='viridis')
ax.set_xlabel("X")
ax.set_ylabel("Y")
fig.colorbar(graph)


plt.show()

# %%
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)

xx, yy = np.meshgrid(x, y)

z = np.tan(np.log2(xx**2 + yy**2 + 1e-10))

fig = plt.figure(figsize=(12, 8))
ax = plt.subplot(projection='3d')

graph = ax.plot_surface(xx, yy, z, cmap='viridis')
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
fig.colorbar(graph)

plt.show()

# %%
fig = plt.figure(figsize=(12, 8))
ax = plt.subplot()

graph = ax.contour(xx, yy, z, cmap='viridis')
ax.set_xlabel("X")
ax.set_ylabel("Y")
fig.colorbar(graph)

plt.show()

# %%
fig = plt.figure(figsize=(12, 8))
ax = plt.subplot()

graph = ax.contourf(xx, yy, z, cmap='viridis')
ax.set_xlabel("X")
ax.set_ylabel("Y")
fig.colorbar(graph)

plt.show()
